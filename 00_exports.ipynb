# %%
#Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# gdrive	sample_data

# %%
#Export 
TEST = 'test'

# %%
# !pip install fire

# %% [markdown]
# # Export

# %%
# !python "/content/drive/My Drive/Colab Notebooks/notebook2script.py" "/content/drive/My Drive/Colab Notebooks/00_exports.ipynb"
# Out:
# Converted /content/drive/My Drive/Colab Notebooks/00_exports.ipynb to /content/drive/My Drive/Colab Notebooks/exp/nb_00.py
